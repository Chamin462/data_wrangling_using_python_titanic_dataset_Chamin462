# %% [markdown]
# # Data Wrangling

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the data set
df = pd.read_csv('titanic.csv')
df1 = pd.read_csv('titanic.csv')
df2 = pd.read_csv('titanic.csv')
df3 = pd.read_csv('titanic.csv')
df4 = pd.read_csv('titanic.csv')
df5 = pd.read_csv('titanic.csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# Check / Printing first / top five rows
# head()   First five rows of dataframe check then head() method.
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
# tail()   Last five rows of dataframe check then tail() method.
df.tail()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# 886         886         0       2    male  27.0      0      0  13.00        S
# 887         887         1       1  female  19.0      0      0  30.00        S
# 888         888         0       3  female   NaN      1      2  23.45        S
# 889         889         1       1    male  26.0      0      0  30.00        C
# 890         890         0       3    male  32.0      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
# shape   you know number of columns and number of rows then use shape() method.
df.shape
# Out:
# (891, 16)

# %%
# describe()  General information of dataset then used describe() method.
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %% [markdown]
# # 1- iloc[]
# # 2- .loc[]
# .iloc and .loc is different is for example 0:3 in .iloc[]method 3 is not include and .loc[]method is 3 is inculde able.

# %%
# iloc[] for [0:3] 3 not include. [0:3] show rows and [0:2] show first two columns of data set / data frame.
df.iloc[0:3,0:2]
# Out:
#    Unnamed: 0  survived
# 0           0         0
# 1           1         1
# 2           2         1

# %%
# iloc[] for [0:5] 5 not include. [0:5] show rows and [0:4] show first four columns of data set / data frame.
df.iloc[0:5,0:4]
# Out:
#    Unnamed: 0  survived  pclass     sex
# 0           0         0       3    male
# 1           1         1       1  female
# 2           2         1       3  female
# 3           3         1       1  female
# 4           4         0       3    male

# %%
# iloc[] for [0:5] 5 not include. [0:5] show rows and [2:] show  columns with out of first two columns of data set / data frame.
df.iloc[0:5,2:]
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 3       1  female  35.0      1      0  53.1000        S  First  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
# .loc[]
# .iloc and .loc is different is for example 0:3 in .iloc[]method 3 is not include and .loc[]method is 3 is inculde able. 
# iloc used columns index and loc[] method columns name.
df.loc[0:10,('sex','age')]
# Out:
#        sex   age
# 0     male  22.0
# 1   female  38.0
# 2   female  26.0
# 3   female  35.0
# 4     male  35.0
# 5     male   NaN
# 6     male  54.0
# 7     male   2.0
# 8   female  27.0
# 9   female  14.0
# 10  female   4.0

# %%
# Now, let’s also the columns and their data types. For this, we will use the info() method.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
# use this method to convert datatype from one to another format
df['survived']=df['survived'].astype('float64')
df.dtypes
# Out:
# Unnamed: 0       int64
# survived       float64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
# simple operations (math operator)
(df['age']+12).head()
# Out:
# 0    34.0
# 1    50.0
# 2    38.0
# 3    47.0
# 4    47.0
# Name: age, dtype: float64

# %%
# here we will convert the age into days instead of years
df['age']=df['age']*365
df.head(10)
# Out:
#    Unnamed: 0  survived  pclass     sex      age  sibsp  parch     fare  \
# 0           0       0.0       3    male   8030.0      1      0   7.2500
# 1           1       1.0       1  female  13870.0      1      0  71.2833
# 2           2       1.0       3  female   9490.0      0      0   7.9250
# 3           3       1.0       1  female  12775.0      1      0  53.1000
# 4           4       0.0       3    male  12775.0      0      0   8.0500
# 5           5       0.0       3    male      NaN      0      0   8.4583
# 6           6       0.0       1    male  19710.0      0      0  51.8625
# 7           7       0.0       3    male    730.0      3      1  21.0750
# 8           8       1.0       3  female   9855.0      0      2  11.1333
# 9           9       1.0       2  female   5110.0      1      0  30.0708
#
#   embarked   class    who  adult_male deck  embark_town alive  alone
# 0        S   Third    man        True  NaN  Southampton    no  False
# ...

# %%
# always rename afterwards
df.rename(columns={'age':'age in day'},inplace=True)
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex  age in day  sibsp  parch     fare  \
# 0           0       0.0       3    male      8030.0      1      0   7.2500
# 1           1       1.0       1  female     13870.0      1      0  71.2833
# 2           2       1.0       3  female      9490.0      0      0   7.9250
# 3           3       1.0       1  female     12775.0      1      0  53.1000
# 4           4       0.0       3    male     12775.0      0      0   8.0500
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# # More Pandas Functions
# 1- Mean()
#
# 2- Median()
#
# 3- Min()
#
# 4- Max()

# %%
name=df['fare'].mean()
name
# Out:
# 32.204207968574636

# %% [markdown]
# # Dropping Columns
# axis = 1 mean drop columns
#
# axis = 0 mean drop rows

# %%
#df.head()

# %%
#df.drop('fare',axis=1,inplace=True)

# %%
#df.drop(['pclass','sex','deck'],axis=1,inplace=True)

# %% [markdown]
# # Dropping Rows

# %%
#df.drop([1,2,3],axis=0,inplace=True)

# %% [markdown]
# # Dealing with missing values
#  - In a data set missing values are either? or N/A or NaN or 0 or a blank cell.
#  - jab kabhi data na ho kisi aik row main kisi b aik parameter ka
# >  Steps:
#    1. Koshish karen dobara data collect kar len ya dekh len agar kahin dhalti hy
#    2. Missing value wala variable (column) hi nikal den agar per effect nahi hta ya simple row or data entry remove kar den
#    3. Replace the missing values
#        1. How ?
#            1. Average value of entire variable or similar point
#            2. Frequencey or Mode replacement
#            3. Replace based on other functions (Data sampler knows that)
#            4. ML algortihm can also be used
#            5. leave it like that
#         2. Why ?
#             1. Its better because no data is lost
#             2. Less accurate

# %% [markdown]
# # Checking Missing Values
# We will check if our data contains any missing values or not. Missing values can occur when no information is provided for one or more items or for a whole unit. We will use the isnull() method.
# # Dealing with missing values

# %% [markdown]
# # Checking Missing Values
# We will check if our data contains any missing values or not. Missing values can occur when no information is provided for one or more items or for a whole unit. We will use the isnull() method.

# %%
df1.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
# where exactly missing values are ?
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1.shape
# Out:
# (891, 16)

# %%
# use dropna method
#df1.dropna(inplace=True)
#df1.dropna()
#df1.dropna(how='all',inplace=True)
df1.dropna(subset=['age','deck','embarked','embark_town'],inplace=True)

# %%
df1.shape
# Out:
# (182, 16)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # Replaceing missing values with the average of the column
# # More Pandas Functions
# 1- Mean()
#
# 2- Median()
#
# 3- Min()
#
# 4- Max()
#
# # Impute / Replace Missing Values with Mean
# #kasur.fillna(kasur.mean(),inplace=True)
#
# #Impute / Replace Missing Values with Median
#
# #lahore.fillna(lahore.median(),inplace=True)
#
# #Impute / Replace Missing Values with Mode
#
# kasur['age'] = kasur['age'].fillna(kasur['age'].mode()[0])
#
# kasur['deck'] = kasur['deck'].fillna(kasur['deck'].mode()[0])

# %%
df2
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df2.shape
# Out:
# (891, 16)

# %%
# simple method is
#mean = df2.mean()
#mean
#median = df2.median()
#median
#min = df2.min()
#min
#max = df2.max()
#max

# %%
# Finding an average mean
mean = df2['age'].mean()
mean
# Out:
# 29.69911764705882

# %%
# replacing NaN with mean of the data (updating as well)
df2['age']=df2['age'].replace(np.nan, mean)

# %%
df2['deck']=df2['deck'].replace(np.nan, mean)

# %%
df2['embark_town']=df2['embark_town'].replace(np.nan, mean)

# %%
df2['embarked']=df2['embarked'].replace(np.nan, mean)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df2.shape
# Out:
# (891, 16)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df3.shape
# Out:
# (891, 16)

# %%
df3['deck'] = df3['deck'].fillna(df3['deck'].mode()[0])
df3['age'] = df3['age'].fillna(df3['age'].mode()[0])
df3['embarked'] = df3['embarked'].fillna(df3['embarked'].mode()[0])

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df3.shape
# Out:
# (891, 16)

# %% [markdown]
# # Checking Duplicates
# Let’s see if our dataset contains any duplicates or not. Pandas drop_duplicates() method helps in removing duplicates from the data frame.

# %% [markdown]
# value_count() know catgoricla values then used vale_count() method.
#
# sort_values()

# %%
df3.value_counts()
# Out:
# Unnamed: 0  survived  pclass  sex     age   sibsp  parch  fare    embarked  class   who    adult_male  deck  embark_town  alive  alone
# 0           0         3       male    22.0  1      0      7.250   S         Third   man    True        C     Southampton  no     False    1
# 598         0         3       male    24.0  0      0      7.225   C         Third   man    True        C     Cherbourg    no     True     1
# 587         1         1       male    60.0  1      1      79.200  C         First   man    True        B     Cherbourg    yes    False    1
# 588         0         3       male    22.0  0      0      8.050   S         Third   man    True        C     Southampton  no     True     1
# 589         0         3       male    24.0  0      0      8.050   S         Third   man    True        C     Southampton  no     True     1
#                                                                                                                                          ..
# ...

# %%
df3['age'].value_counts()
# Out:
# 24.00    207
# 22.00     27
# 18.00     26
# 28.00     25
# 30.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 88, dtype: int64

# %%
df3['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
df3.sort_values(by='fare')
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 271         271         1       3    male  25.0      0      0    0.0000
# 597         597         0       3    male  49.0      0      0    0.0000
# 302         302         0       3    male  19.0      0      0    0.0000
# 633         633         0       1    male  24.0      0      0    0.0000
# 277         277         0       2    male  24.0      0      0    0.0000
# ..          ...       ...     ...     ...   ...    ...    ...       ...
# 438         438         0       1    male  64.0      1      4  263.0000
# 341         341         1       1  female  24.0      3      2  263.0000
# 737         737         1       1    male  35.0      0      0  512.3292
# 258         258         1       1  female  35.0      0      0  512.3292
# 679         679         1       1    male  36.0      0      1  512.3292
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
#data = df3.drop_duplicates(subset ="class")
data = df.drop_duplicates()
data
# Out:
#      Unnamed: 0  survived  pclass     sex  age in day  sibsp  parch     fare  \
# 0             0       0.0       3    male      8030.0      1      0   7.2500
# 1             1       1.0       1  female     13870.0      1      0  71.2833
# 2             2       1.0       3  female      9490.0      0      0   7.9250
# 3             3       1.0       1  female     12775.0      1      0  53.1000
# 4             4       0.0       3    male     12775.0      0      0   8.0500
# ..          ...       ...     ...     ...         ...    ...    ...      ...
# 886         886       0.0       2    male      9855.0      0      0  13.0000
# 887         887       1.0       1  female      6935.0      0      0  30.0000
# 888         888       0.0       3  female         NaN      1      2  23.4500
# 889         889       1.0       1    male      9490.0      0      0  30.0000
# 890         890       0.0       3    male     11680.0      0      0   7.7500
#
# ...

# %%
df3.value_counts()
# Out:
# Unnamed: 0  survived  pclass  sex     age   sibsp  parch  fare    embarked  class   who    adult_male  deck  embark_town  alive  alone
# 0           0         3       male    22.0  1      0      7.250   S         Third   man    True        C     Southampton  no     False    1
# 598         0         3       male    24.0  0      0      7.225   C         Third   man    True        C     Cherbourg    no     True     1
# 587         1         1       male    60.0  1      1      79.200  C         First   man    True        B     Cherbourg    yes    False    1
# 588         0         3       male    22.0  0      0      8.050   S         Third   man    True        C     Southampton  no     True     1
# 589         0         3       male    24.0  0      0      8.050   S         Third   man    True        C     Southampton  no     True     1
#                                                                                                                                          ..
# ...

# %% [markdown]
# - Above data is really is wide range and we need to normalize and hard to compare.
# - Normalization change the values to the range of 0 to 1 (now both variable has similar influnce on our models.)
#
# # Method of Normalization
#  1- Simple feature scaling\
#       - x(new)=x(old)/x(max)\
#  2- Min-Max Method\
#  3- Z-score (standard score) -3 to +3\
#  4- Long transformation\

# %%
df4.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df_4 =df4[['age','fare']]
df_4.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
# simple feature scalling
df4['fare']=df4['fare']/df4['fare'].max()
df4['age']=df4['age']/df4['age'].max()
df4.head()
# Out:
#    Unnamed: 0  survived  pclass     sex     age  sibsp  parch      fare  \
# 0           0         0       3    male  0.2750      1      0  0.014151
# 1           1         1       1  female  0.4750      1      0  0.139136
# 2           2         1       3  female  0.3250      0      0  0.015469
# 3           3         1       1  female  0.4375      1      0  0.103644
# 4           4         0       3    male  0.4375      0      0  0.015713
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
# Min Max Method
df4['fare']=(df4['fare']-df4['fare'].min())/(df4['fare'].max()-df4['fare'].min())
df4['age']=(df4['age']-df4['age'].min())/(df4['age'].max()-df4['age'].min())
df4.head()
# Out:
#    Unnamed: 0  survived  pclass     sex       age  sibsp  parch      fare  \
# 0           0         0       3    male  0.271174      1      0  0.014151
# 1           1         1       1  female  0.472229      1      0  0.139136
# 2           2         1       3  female  0.321438      0      0  0.015469
# 3           3         1       1  female  0.434531      1      0  0.103644
# 4           4         0       3    male  0.434531      0      0  0.015713
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
# Z-score (standard score)
df4['fare']=(df4['fare']-df4['fare'].mean())/df4['fare'].std()
df4['age']=(df4['age']-df4['age'].mean())/df4['age'].std()
df4.head()
# Out:
#    Unnamed: 0  survived  pclass     sex       age  sibsp  parch      fare  \
# 0           0         0       3    male -0.530005      1      0 -0.502163
# 1           1         1       1  female  0.571430      1      0  0.786404
# 2           2         1       3  female -0.254646      0      0 -0.488580
# 3           3         1       1  female  0.364911      1      0  0.420494
# 4           4         0       3    male  0.364911      0      0 -0.486064
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
# log transformation
df4['fare']=np.log(df4['fare'])
df4.head()
# Out:
# C:\Users\Ch\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Unnamed: 0  survived  pclass     sex       age  sibsp  parch      fare  \
# 0           0         0       3    male -0.530005      1      0       NaN
# 1           1         1       1  female  0.571430      1      0 -0.240285
# 2           2         1       3  female -0.254646      0      0       NaN
# 3           3         1       1  female  0.364911      1      0 -0.866325
# 4           4         0       3    male  0.364911      0      0       NaN
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# ...

# %%
min_value = df4['age'].min()
max_value = df4['age'].max()
print(min_value)
print(max_value)
# Out:
# -2.015566242654203
# 3.462698625977656

# %% [markdown]
# # Binning
# - Grouping of values into smaller number of value (bins)
# - Convert numeric into categories ('jawan','bachay','boorhay')0r1-16 or 17-30 etc
# - To have batter understanding of groups
#     - low vs mid vs high price

# %% [markdown]
# # Binning Data in Pandas with cut and qcut
#
# # What is Binning in Pandas and Python?
# In many cases when dealing with continuous numeric data (such as ages, sales, or incomes), it can be helpful to create bins of your data. Binning data will convert data into discrete buckets, allowing you to gain insight into your data in logical ways. Binning data is also often referred to under several other terms, such as discrete binning, quantization, and discretization.
#
# In this tutorial, you’ll learn about two different Pandas methods, .cut() and .qcut() for binning your data. These methods will allow you to bin data into custom-sized bins and equally-sized bins, respectively. Equal-sized bins allow you to gain easy insight into the distribution, while grouping data into custom bins can allow you to gain insight into logical categorical groupings.
# # Pandas qcut: Binning Data into Equal-Sized Bins
# The Pandas .qcut() method splits your data into equal-sized buckets, based on rank or some sample quantiles. This process is known as quantile-based discretization. Let’s take a look at the parameters available in the function:
# # Parameters of the Pandas .qcut() method
# ```
#  pd.qcut(
#     x,                      # Column to bin
#     q,                      # Number of quantiles
#     labels=None,            # List of labels to include
#     retbins=False,          # Whether to return the bins/labels or not
#     precision=3,            # The precision to store and display the bins labels
#     duplicates='raise'      # If bin edges are not unique, raise a ValueError
# )
# ```
# # Splitting Age Column into Four Quantiles
# ```
# df['Age Groups'] = pd.qcut(df['Age'], 4)
# print(df.head())
# ```

# %%
df5
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# Splitting Age Column into Four Quantiles
df5['Age Groups'] = pd.qcut(df5['age'], 4)
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone      Age Groups
# 0  Third    man        True  NaN  Southampton    no  False  (20.125, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False    (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.125, 28.0]
# 3  First  woman       False    C  Southampton   yes  False    (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True    (28.0, 38.0]

# %%
# Checking the data type of the qcut column
df5['Age Groups'] = pd.qcut(df5['age'], 4)
print(df5['Age Groups'].dtype)
# Out:
# category

# %%
print(df5['Age Groups'].dtype)
# Out:
# category

# %%
# Splitting Age Column into Four Quantiles
df5['Age Groups'] = pd.qcut(df5['age'],[0, 0.25, 0.5, 0.75, 1])
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone      Age Groups
# 0  Third    man        True  NaN  Southampton    no  False  (20.125, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False    (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.125, 28.0]
# 3  First  woman       False    C  Southampton   yes  False    (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True    (28.0, 38.0]

# %%
# Adding Labels to Pandas .qcut()
df5['Age Groups'] = pd.qcut(df5['age'],[0, 0.25, 0.5, 0.75, 1],labels=['0-25%', '26-49%', '51-75%', '76-100%'])
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone Age Groups
# 0  Third    man        True  NaN  Southampton    no  False     26-49%
# 1  First  woman       False    C    Cherbourg   yes  False     51-75%
# 2  Third  woman       False  NaN  Southampton   yes   True     26-49%
# 3  First  woman       False    C  Southampton   yes  False     51-75%
# 4  Third    man        True  NaN  Southampton    no   True     51-75%

# %%
# Modifying Precision in Categories
df5['Age Groups'] = pd.qcut(df5['age'],4,precision=1)
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]

# %%
# Parameters of the .cut() Function
###
# pd.cut(
#   x,                          # The input array to be binned
#  bins,                       # The bins to use: int (# of bins) or sequence (widths) 
  #  right=True,                 # Whether to include right-most edge
 #   labels=None,                # Labels to be used for bins
  #  retbins=False,              # Whether to return bins or not
 #   precision=3,                # Precision to store and display bins
  #  include_lowest=False,       # Whether first interval should be left inclusive or not
  #  duplicates='raise',         # What to do if bins edges are not unique
 #   ordered=True                # Whether labels are ordered or not
#)

# %%
df5['Age Group'] = pd.cut(df5['age'],[0, 17, 64, 100])
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#   Age Group
# 0  (17, 64]
# 1  (17, 64]
# 2  (17, 64]
# ...

# %%
# Adding labels to the groupings
df5['Age Group'] = pd.cut(df5['age'],[0, 17, 64, 100], labels=['0-18 years old', '18-65 years old', '65+ years old'])
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group
# 0  18-65 years old
# ...

# %%
# Using the right= argument to modify binning behavior
df5['Age Group'] = pd.cut(df5['age'],[0, 18, 65, 100],labels=['0-18 years old', '18-65 years old', '65+ years old'],right=False)
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group
# 0  18-65 years old
# ...

# %%
# Including left-most values
df5['Age Group'] = pd.cut(df5['age'],[0, 18, 65, 100],labels=['0-18 years old', '18-65 years old', '65+ years old'],include_lowest=True)
df5.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group
# 0  18-65 years old
# ...

# %%
# Creating Ordered Categories
print(pd.cut( df5['age'],[0, 18, 65, 100],labels=['0-18 years old', '18-65 years old', '65+ years old'],ordered=True))
# Out:
# 0      18-65 years old
# 1      18-65 years old
# 2      18-65 years old
# 3      18-65 years old
# 4      18-65 years old
#             ...
# 886    18-65 years old
# 887    18-65 years old
# 888                NaN
# 889    18-65 years old
# 890    18-65 years old
# Name: age, Length: 891, dtype: category
# Categories (3, object): ['0-18 years old' < '18-65 years old' < '65+ years old']

# %% [markdown]
# # Conclusion and Recap
# In this tutorial, you learned how to bin your data in Python and Pandas using the cut and qcut functions. The section below provides a recap of what you learned:
#
# The Pandas qcut function bins data into an equal distributon of items
# The Pandas cut function allows you to define your own ranges of data
# Binning your data allows you to both get a better understanding of the distribution of your data as well as creating logical categories based on other abstractions
# Both functions gives you flexibility in defining and displaying your bins

# %% [markdown]
# # Converting categories into dummies
# - Easy to use for computation
# - Male, Female (0,1)

# %%
get=pd.get_dummies(df5['sex'])
df5.head()

# how to use get dummies to change data inside a dataframe
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0  Third    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  First  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  Third  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  First  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4  Third    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group
# 0  18-65 years old
# ...

# %%
# transfer into dummy values?
df4.head()
# Out:
#    Unnamed: 0  survived  pclass     sex       age  sibsp  parch      fare  \
# 0           0         0       3    male -0.530005      1      0       NaN
# 1           1         1       1  female  0.571430      1      0 -0.240285
# 2           2         1       3  female -0.254646      0      0       NaN
# 3           3         1       1  female  0.364911      1      0 -0.866325
# 4           4         0       3    male  0.364911      0      0       NaN
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
# Creating dummy variables from one column
get = pd.get_dummies(df5,columns=['sex'])
get.head()
# Out:
#    Unnamed: 0  survived  pclass   age  sibsp  parch     fare embarked  class  \
# 0           0         0       3  22.0      1      0   7.2500        S  Third
# 1           1         1       1  38.0      1      0  71.2833        C  First
# 2           2         1       3  26.0      0      0   7.9250        S  Third
# 3           3         1       1  35.0      1      0  53.1000        S  First
# 4           4         0       3  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group  sex_female  sex_male
# 0  18-65 years old           0         1
# ...

# %%
# Changing the prefix for the dummy variables:
df_dummies = pd.get_dummies(df5, prefix='Gender', prefix_sep='.',  columns=['sex'])
df_dummies.head()
# Out:
#    Unnamed: 0  survived  pclass   age  sibsp  parch     fare embarked  class  \
# 0           0         0       3  22.0      1      0   7.2500        S  Third
# 1           1         1       1  38.0      1      0  71.2833        C  First
# 2           2         1       3  26.0      0      0   7.9250        S  Third
# 3           3         1       1  35.0      1      0  53.1000        S  First
# 4           4         0       3  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone    Age Groups  \
# 0    man        True  NaN  Southampton    no  False  (20.1, 28.0]
# 1  woman       False    C    Cherbourg   yes  False  (28.0, 38.0]
# 2  woman       False  NaN  Southampton   yes   True  (20.1, 28.0]
# 3  woman       False    C  Southampton   yes  False  (28.0, 38.0]
# 4    man        True  NaN  Southampton    no   True  (28.0, 38.0]
#
#          Age Group  Gender.female  Gender.male
# 0  18-65 years old              0            1
# ...

# %%
# Remove the prefix and separator when dummy coding:
df_dummies = pd.get_dummies(df, prefix='Gender', prefix_sep='.', columns=['sex'])
df_dummies.head()
# Out:
#    Unnamed: 0  survived  pclass  age in day  sibsp  parch     fare embarked  \
# 0           0       0.0       3      8030.0      1      0   7.2500        S
# 1           1       1.0       1     13870.0      1      0  71.2833        C
# 2           2       1.0       3      9490.0      0      0   7.9250        S
# 3           3       1.0       1     12775.0      1      0  53.1000        S
# 4           4       0.0       3     12775.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone  Gender.female  \
# 0  Third    man        True  NaN  Southampton    no  False              0
# 1  First  woman       False    C    Cherbourg   yes  False              1
# 2  Third  woman       False  NaN  Southampton   yes   True              1
# 3  First  woman       False    C  Southampton   yes  False              1
# 4  Third    man        True  NaN  Southampton    no   True              0
#
#    Gender.male
# 0            1
# 1            0
# ...

# %% [markdown]
# # Data Visualization
# ## Visualizing the target column

# %%
df2.shape
# Out:
# (891, 16)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df2.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male       deck  embark_town alive  alone
# 0  Third    man        True  29.699118  Southampton    no  False
# 1  First  woman       False          C    Cherbourg   yes  False
# 2  Third  woman       False  29.699118  Southampton   yes   True
# 3  First  woman       False          C  Southampton   yes  False
# 4  Third    man        True  29.699118  Southampton    no   True

# %%
df1.shape
# Out:
# (182, 16)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df1.head()
# Out:
#     Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 1            1         1       1  female  38.0      1      0  71.2833
# 3            3         1       1  female  35.0      1      0  53.1000
# 6            6         0       1    male  54.0      0      0  51.8625
# 10          10         1       3  female   4.0      1      1  16.7000
# 11          11         1       1  female  58.0      0      0  26.5500
#
#    embarked  class    who  adult_male deck  embark_town alive  alone
# 1         C  First  woman       False    C    Cherbourg   yes  False
# 3         S  First  woman       False    C  Southampton   yes  False
# 6         S  First    man        True    E  Southampton    no   True
# 10        S  Third  child       False    G  Southampton   yes  False
# 11        S  First  woman       False    C  Southampton   yes   True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Box plot
sns.set(style="whitegrid")
sns.boxplot(x="sex", y="age",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.set(style="whitegrid")
sns.boxplot(y="age",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.set(style="whitegrid")
sns.boxplot(x="fare", y="sex",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='sex'>

# %%
sns.set(style="whitegrid")
sns.boxplot( y="fare",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:ylabel='fare'>

# %%
# filter out
# out liers removal
df1=df1[df1['fare']<200]

# %%
sns.set(style="whitegrid")
sns.boxplot( y="fare",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:ylabel='fare'>

# %%
sns.set(style="whitegrid")
sns.boxplot(x="sex", y="fare",data=df1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
# Box plot
sns.set(style="whitegrid")
sns.boxplot(x="sex", y="age",data=df2,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.set(style="whitegrid")
sns.boxplot( y="age",data=df2,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
# filter out
# out liers removal
df2_c1=df2[df2['age']<55]
df2_c2=df2[df2['age']>8]

# %%
sns.set(style="whitegrid")
sns.boxplot( y="age",data=df2_c1,hue="alive",palette="Set2",dodge=True)
# Out:
# <AxesSubplot:ylabel='age'>
